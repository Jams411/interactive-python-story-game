# %%
import time

# 🎤 Intro
print("🎬 Welcome to the WORST 5 minutes of someone’s life.")
print("⚠️ Rule: The worse your answers, the better this gets.\n")

# 😂 Funny prompts before each input
print("Alright… who is today's victim? 😈")
name = input("👤 Enter a name (friend, celeb, professor… be bold): ")

print("\nWe need a smell that should be illegal...")
gross_thing = input("🤢 Something disgusting (e.g., wet socks, expired milk, gym locker): ")

print("\nWhere will this disaster happen?")
place = input("📍 Enter a place (classroom, subway, wedding, job interview): ")

print("\nTime for public humiliation...")
action = input("😬 Embarrassing action (tripped, farted loudly, sneezed on someone): ")

print("\nFinal touch… something they should NEVER eat.")
food = input("🍜 Weird food (pickle ice cream, banana pizza, chocolate + ketchup): ")

print("\n⏳ Generating disaster...\n")
time.sleep(2)

# 🎭 Story begins
print("\n--- THE WORST 5 MINUTES OF YOUR LIFE ---\n")

print(f"{name} walked into the {place}, feeling confident.")
time.sleep(2)

print("Too confident.")
time.sleep(2)

print("Suddenly… a smell hit the room.")
time.sleep(2)

print(f"Someone whispered: 'What is that? Smells like {gross_thing}.'")
time.sleep(2)

print(f"{name} froze.")
time.sleep(2)

print(f"{name}: 'That’s… not me.'")
time.sleep(2)

print("Everyone stared.")
time.sleep(2)

print(f"A random kid stood up and yelled: 'IT'S {name}!'")
time.sleep(2)

print("Chaos.")
time.sleep(2)

print(f"In panic, {name} tried to act normal… and accidentally {action}.")
time.sleep(2)

print("Dead silence.")
time.sleep(2)

print("Then someone in the back made a noise:")
time.sleep(2)

print('"BRUUUUH."')
time.sleep(2)

print(f"Trying to recover, {name} grabbed some {food} and took a big bite.")
time.sleep(2)

print("Instant regret.")
time.sleep(2)

print(f"{name}: 'Why did I do that…'")
time.sleep(2)

print("Teacher walks in. Looks around. Leaves immediately.")
time.sleep(2)

print(f"At that moment, {name} accepted their fate.")
time.sleep(2)

print("Reputation: destroyed.")
time.sleep(2)

print("Dignity: gone.")
time.sleep(2)

print("Legend status: unlocked.")
time.sleep(2)

print("\nTHE END.\n")
# Out:
# 🎬 Welcome to the WORST 5 minutes of someone’s life.
# ⚠️ Rule: The worse your answers, the better this gets.
#
# Alright… who is today's victim? 😈
# 👤 Enter a name (friend, celeb, professor… be bold): Tom
#
# We need a smell that should be illegal...
# 🤢 Something disgusting (e.g., wet socks, expired milk, gym locker): stinky jacket
#
# Where will this disaster happen?
# 📍 Enter a place (classroom, subway, wedding, job interview): classroom
#
# Time for public humiliation...
# 😬 Embarrassing action (tripped, farted loudly, sneezed on someone): fainted
#
# Final touch… something they should NEVER eat.
# 🍜 Weird food (pickle ice cream, banana pizza, chocolate + ketchup): pickle cake
#
# ⏳ Generating disaster...
#
#
# --- THE WORST 5 MINUTES OF YOUR LIFE ---
#
# Tom walked into the classroom, feeling confident.
# Too confident.
# Suddenly… a smell hit the room.
# Someone whispered: 'What is that? Smells like stinky jacket.'
# Tom froze.
# Tom: 'That’s… not me.'
# Everyone stared.
# A random kid stood up and yelled: 'IT'S Tom!'
# Chaos.
# In panic, Tom tried to act normal… and accidentally fainted.
# Dead silence.
# Then someone in the back made a noise:
# "BRUUUUH."
# Trying to recover, Tom grabbed some pickle cake and took a big bite.
# Instant regret.
# Tom: 'Why did I do that…'
# Teacher walks in. Looks around. Leaves immediately.
# At that moment, Tom accepted their fate.
# Reputation: destroyed.
# Dignity: gone.
# Legend status: unlocked.
#
# THE END.
